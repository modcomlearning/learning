# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='58c54d8e-cc40-47e3-a187-5ebe06766021', project_access_token='p-f33cfcb606996eb141e3fe49d3f600722388bf29')
pc = project.project_context

# %%
import pandas
dataset = pandas.read_csv("http://modcom.co.ke/datasets/Advertising.csv")
#print(dataset)

# We create a Model to predict Sales from the dataset
array = dataset.values
#print(array)

# What are we predicting? Sales
# 1st colon means all rows
X = array[:, 1:4]  # means 0...3, 4 is not here : 
Y = array[:, 4]

# Now that we have the X(Features), Y(Outcome)
print(dataset.shape)
print(dataset.describe())


# Load the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Fit X(Features) and Y (outcome).
model.fit(X,Y)

# Deployed the model
# Out:
# (200, 5)
#                No          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000
# To Sell:  [3773.53922773]

# %%
import pandas
customers = pandas.read_csv("http://modcom.co.ke/datasets/Customers.csv")
print(customers)
# Out:
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# 5    645 Martha Park Apt. 611\nJeffreychester, MN 6...       FloralWhite
# 6    68388 Reyes Lights Suite 692\nJosephbury, WV 9...     DarkSlateBlue
# 7                Unit 6538 Box 8980\nDPO AP 09026-4941              Aqua
# 8               860 Lee Key\nWest Debra, SD 97450-0495            Salmon
# 9                PSC 2734, Box 5255\nAPO AA 98456-7482             Brown
# 10   26104 Alexander Groves\nAlexandriaport, WY 282...            Tomato
# 11               Unit 2413 Box 0347\nDPO AA 07580-2652            Tomato
# ...
